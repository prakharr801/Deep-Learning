# %%
import pandas as pd
import numpy as np


import plotly.express as px
import plotly.graph_objects as go

from sklearn.model_selection import train_test_split

# %%
from sklearn.datasets import make_regression
X,y = make_regression(n_samples=1000, n_features=2, n_targets=1, noise=50)

# %%
df = pd.DataFrame({'feature1':X[:,0],'featur2':X[:,1],'target':y})
df.shape
# Out:
# (1000, 3)

# %%
df.head()
# Out:
#    feature1   featur2     target
# 0 -0.411541  2.007972  33.557951
# 1 -0.576609 -0.665324 -20.097016
# 2  0.074538 -1.941083  71.792151
# 3  1.204314  1.404531  65.804830
# 4  0.608481  0.648882  39.614907

# %%
fig = px.scatter_3d(df, x='feature1', y='featur2', z='target')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
print(f'MSE: {mean_squared_error(y_test, y_pred)}')
print(f'MAE: {mean_absolute_error(y_test, y_pred)}')
print(f'R2: {r2_score(y_test, y_pred)}')
# Out:
# MSE: 2478.266291993624
# MAE: 40.32442019930375
# R2: 0.5694643278187947

# %%
new_input = np.array([[-0.4, 0.78]])

# %%
predicted_target = lr.predict(new_input)
print("Predicted Target:", predicted_target[0])
# Out:
# Predicted Target: -0.1155317411463812

# %%
x = np.linspace(-10,10,100)
y = np.linspace(-10,10,100)
xgrid, ygrid = np.meshgrid(y,x)

final = np.vstack([xgrid.ravel(), ygrid.ravel()]).T

z_final = lr.predict(final).reshape(100,100)

z = z_final

# %%
fig = px.scatter_3d(df, x='feature1', y='featur2', z='target')
fig.add_traces(go.Surface(x=x, y=y, z=z))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip "/content/drive/MyDrive/ML Pipelines/COLAB NOTEBOOK/archive (2).zip" -d "/tmp/extracted_files"
# Out:
# Archive:  /content/drive/MyDrive/ML Pipelines/COLAB NOTEBOOK/archive (2).zip
#   inflating: /tmp/extracted_files/multiple_linear_regression_dataset.csv

# %%
dm= pd.read_csv('/tmp/extracted_files/multiple_linear_regression_dataset.csv')
dm.head()
# Out:
#    age  experience  income
# 0   25           1   30450
# 1   30           3   35670
# 2   47           2   31580
# 3   32           5   40130
# 4   43          10   47830

# %%
fig = px.scatter_3d(dm, x='age', y='experience', z='income')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
lr.coef_
# Out:
# array([43.34267704, 20.5371502 ])

# %%
lr.intercept_
# Out:
# np.float64(1.2025619228308522)
