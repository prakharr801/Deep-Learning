# %%
# !pip install ydata-profiling
# Out:
# ...
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# ...
#    ---------------------------------------- 0.0/678.1 kB ? eta -:--:--
#    ---------------------------------------- 678.1/678.1 kB 2.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    ------------- -------------------------- 1.0/3.1 MB 5.2 MB/s eta 0:00:01
#    ------------- -------------------------- 1.0/3.1 MB 5.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.3/3.1 MB 1.8 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.3/3.1 MB 1.8 MB/s eta 0:00:01
#    -------------------- ------------------- 1.6/3.1 MB 1.5 MB/s eta 0:00:02
#    -------------------- ------------------- 1.6/3.1 MB 1.5 MB/s eta 0:00:02
#    -------------------- ------------------- 1.6/3.1 MB 1.5 MB/s eta 0:00:02
#    ----------------------- ---------------- 1.8/3.1 MB 1.1 MB/s eta 0:00:02
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv("Ice_cream.csv")

# %%
#Create a profile report
from ydata_profiling import ProfileReport

profile=ProfileReport(df, title="Ice Cream Data Profiling Report", explorative=True)

#save as html file
profile.to_file("Ice_Cream_Data_Profiling_Report.html")

#Optional: Display the report in the notebook
profile.to_notebook_iframe()
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# ...
